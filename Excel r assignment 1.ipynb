# %%
import pandas as pd
df=pd.read_csv("C://Users//mvish//Desktop//sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
mean_value=df["Volume"].mean()
mean_value
# Out:
# 5.066666666666666

# %%
mode_value=df["Volume"].mode()
mode_value
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
median_value=df["Volume"].median()
median_value
# Out:
# 4.0

# %%
std_value=df["Volume"].std()
std_value
# Out:
# 4.231602391213926

# %%
numerical_columns=["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]
result_dict={}
for column in numerical_columns:
    mean=df[column].mean()
    median=df[column].median()
    mode=df[column].mode()
    std_dev=df[column].std()
    result_dict[column] = {'Mean': mean, 'Median': median, 'Mode': mode, 'Standard Deviation': std_dev}
result_df=pd.DataFrame(result_dict)
print(result_df)
# Out:
#                                                Volume  \
# Mean                                         5.066667
# Median                                            4.0
# Mode                0    3
# Name: Volume, dtype: int64
# Standard Deviation                           4.231602
#
#                                                             Avg Price  \
# Mean                                                     10453.433333
# Median                                                         1450.0
# Mode                0     400
# 1     450
# 2     500
# 3    1300
# 4    8...
# Standard Deviation                                        18079.90484
#
#                                                    Total Sales Value  \
# Mean                                                    33812.835556
# Median                                                        5700.0
# Mode                0    24300
# Name: Total Sales Value, dtype: int64
# ...

# %%
from matplotlib import pyplot as plt

# %%
df["Volume"].hist()
# Out:
# <Axes: >

# %%
column_names = ["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]

num_plots = len(column_names)
num_cols = 3
num_rows = 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6))
axes = axes.flatten()

for i, column in enumerate(column_names):
    ax = axes[i]
    df[column].hist(ax=ax)
    ax.set_title(f'Histogram of {column}')
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')



plt.tight_layout()
plt.show()

# %%
column_names = ["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]
statsitics=df[column_names].describe()
statsitics
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
skewness=df[column_names].skew()
skewness
# Out:
# Volume               2.731724
# Avg Price            1.908873
# Total Sales Value    1.534729
# Discount Rate (%)   -1.062294
# Discount Amount      1.913038
# Net Sales Value      1.540822
# dtype: float64

# %%
numerical_columns = ["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]
Q1 = df[numerical_columns].quantile(0.25)
Q3 = df[numerical_columns].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = ((df[numerical_columns] < lower_bound) | (df[numerical_columns] > upper_bound))

print("\nOutliers:")
print(outliers.sum())
# Out:
# Outliers:
# Volume               44
# Avg Price            60
# Total Sales Value    36
# Discount Rate (%)    45
# Discount Amount      24
# Net Sales Value      35
# dtype: int64

# %%
column_names = ["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]
df[column_names].boxplot(figsize=(10, 6))
plt.title('Boxplot of Numerical Columns')
plt.ylabel('Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)  
plt.grid(False) 
plt.show()

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
categorical_columns = ["Date", "Day", "SKU", "City", "Volume", "BU", "Brand", "Model"]
for column in categorical_columns:
    category_counts = df[column].value_counts()
    plt.figure(figsize=(10, 6))
    category_counts.plot(kind='bar')
    plt.title(f'Frequency of Categories in {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)  
    plt.show()

    print(f"Top categories in {column}:")
    print(category_counts.head())
    print("\n")
# Out:
# Top categories in Date:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# Name: count, dtype: int64
# Top categories in Day:
# Day
# Thursday    90
# Friday      60
# Saturday    60
# Sunday      60
# Monday      60
# Name: count, dtype: int64
# Top categories in SKU:
# SKU
# M01    15
# M02    15
# L09    15
# L08    15
# L07    15
# Name: count, dtype: int64
# Top categories in City:
# City
# C    450
# Name: count, dtype: int64
# Top categories in Volume:
# Volume
# 3    110
# 2     76
# 4     61
# 6     38
# 5     38
# Name: count, dtype: int64
# Top categories in BU:
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64
# Top categories in Brand:
# Brand
# Jeera    90
# Gear     60
# Viva     60
# RealU    45
# YouM     45
# Name: count, dtype: int64
# Top categories in Model:
# Model
# RU-10        15
# RU-9 Plus    15
# M-Formals    15
# W-Lounge     15
# W-Western    15
# ...

# %%
 numerical_columns = ["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
for column in numerical_columns:
    df[column].hist(alpha=0.5, label=column)
plt.title('Before Standardization')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()

for column in numerical_columns:
    mean = df[column].mean()
    std_dev = df[column].std()
    df[column] = (df[column] - mean) / std_dev
plt.subplot(1, 2, 2)
for column in numerical_columns:
    df[column].hist(alpha=0.5, label=column)
plt.title('After Standardization')
plt.xlabel('Values (Standardized)')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
df
# Out:
#            Date       Day  SKU City    Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C  2.347417    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C  1.165831    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C  0.456880    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C  0.220563    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C -0.488389    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...       ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C -0.724706  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  0.220563  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C -0.724706  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C -0.488389  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C -0.961023  Lifestyle  Jeera     M-Shoes
#
# ...

# %%
numerical_columns = ["Day","SKU","City","BU","Brand","Model"]
df.drop(numerical_columns,axis="columns")
numerical_columns
# Out:
# ['Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %%
non_columns=df[["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]]
non_columns
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.347417   0.091072           2.922469          -0.829365
# 1    1.165831  -0.019548           1.329516          -0.851714
# 2    0.456880   0.312312           1.561038          -1.350129
# 3    0.220563   0.533552           1.717365          -1.947555
# 4   -0.488389  -0.130168          -0.188242           0.672990
# ..        ...        ...                ...                ...
# 445 -0.724706  -0.506277          -0.617647           0.075924
# 446  0.220563  -0.434374          -0.360400           0.450596
# 447 -0.724706  -0.489684          -0.605774           0.902788
# 448 -0.488389  -0.473091          -0.556303           0.388042
# 449 -0.961023  -0.406719          -0.607753           0.042188
#
#      Discount Amount  Net Sales Value
# 0           3.948422         2.801638
# 1           1.846958         1.269613
# 2           1.621190         1.543957
# 3           1.112568         1.763847
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le_Day = LabelEncoder()
le_SKU = LabelEncoder()
le_City	= LabelEncoder()
le_BU = LabelEncoder()
le_Brand = LabelEncoder()	
le_Model = LabelEncoder()

numerical_columns['Day_n'] = le_Day.fit_transform(numerical_columns['Day'])
numerical_columns['SKU_n'] = le_SKU.fit_transform(numerical_columns['SKU'])
numerical_columns['City_n'] = le_City.fit_transform(numerical_columns['City'])
numerical_columns['BU_n'] = le_BU.fit_transform(numerical_columns['BU'])
numerical_columns['Brand_n'] = le_Brand.fit_transform(numerical_columns['Brand'])
numerical_columns['Model_n']=le_Model.fit_transform(numerical_columns['Model'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 10
#       7 le_Brand = LabelEncoder()
#       8 le_Model = LabelEncoder()
# ---> 10 numerical_columns['Day_n'] = le_Day.fit_transform(numerical_columns['Day'])
#      11 numerical_columns['SKU_n'] = le_SKU.fit_transform(numerical_columns['SKU'])
#      12 numerical_columns['City_n'] = le_City.fit_transform(numerical_columns['City'])
#
# TypeError: list indices must be integers or slices, not str
