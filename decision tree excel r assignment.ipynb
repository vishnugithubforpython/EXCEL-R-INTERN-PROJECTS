# %%
import pandas as pd

# %%
heart_disease=pd.read_excel("heart_disease.xlsx",sheet_name='Heart_disease')
df=heart_disease.copy()
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
df.describe()
# Out:
#               age    trestbps        chol      thalch     oldpeak         num
# count  908.000000  908.000000  908.000000  908.000000  846.000000  908.000000
# mean    53.791850  133.430617  201.484581  135.957048    0.891253    1.008811
# std      9.158031   20.401608  112.097949   26.804929    1.093875    1.144436
# min     29.000000    0.000000    0.000000   60.000000   -2.600000    0.000000
# 25%     47.750000  120.000000  176.750000  118.000000    0.000000    0.000000
# 50%     54.000000  130.000000  224.000000  138.000000    0.500000    1.000000
# 75%     60.000000  144.000000  270.000000  156.000000    1.500000    2.000000
# max     77.000000  200.000000  603.000000  202.000000    6.200000    4.000000

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
df.fillna(0,inplace=True)
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
few=df.drop(["age" ,"trestbps","chol","thalch","oldpeak","num"],axis=1)
few
# Out:
#       sex               cp    fbs           restecg  exang        slope  \
# 0    Male   typical angina   True    lv hypertrophy  False  downsloping
# 1    Male  atypical angina  False            normal  False         flat
# 2    Male     asymptomatic  False            normal  False         flat
# 3    Male   typical angina  False    lv hypertrophy  False         flat
# 4    Male     asymptomatic  False            normal   True         flat
# ..    ...              ...    ...               ...    ...          ...
# 903  Male     asymptomatic  False            normal  False    upsloping
# 904  Male     asymptomatic  False  st-t abnormality   True         flat
# 905  Male      non-anginal  False    lv hypertrophy   True  downsloping
# 906  Male      non-anginal   True  st-t abnormality   TURE  downsloping
# 907  Male     asymptomatic   True  st-t abnormality  FALSE         flat
#
#                   thal
# 0         fixed defect
# 1         fixed defect
# 2         fixed defect
# ...

# %%
from matplotlib import pyplot as plt

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'thalch'}>],
#        [<Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'num'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame

# Histograms of all numeric features
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# Box plots of all numeric features
plt.figure(figsize=(12, 10))
sns.boxplot(data=df)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# Correlation matrix
plt.figure(figsize=(12, 10))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\mvish\AppData\Local\Temp\ipykernel_44080\384561333.py:19: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
target=df.drop(["age","sex","cp","trestbps","chol","fbs","restecg","thalch","exang","oldpeak","slope","num"],axis=1)
target
# Out:
#                   thal
# 0         fixed defect
# 1         fixed defect
# 2         fixed defect
# 3         fixed defect
# 4         fixed defect
# ..                 ...
# 903  reversable defect
# 904  reversable defect
# 905             normal
# 906       fixed defect
# 907  reversable defect
#
# [908 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le_thal=LabelEncoder()
target["thals"]=le_thal.fit_transform(target["thal"])
target
# Out:
#                   thal  thals
# 0         fixed defect      0
# 1         fixed defect      0
# 2         fixed defect      0
# 3         fixed defect      0
# 4         fixed defect      0
# ..                 ...    ...
# 903  reversable defect      2
# 904  reversable defect      2
# 905             normal      1
# 906       fixed defect      0
# 907  reversable defect      2
#
# [908 rows x 2 columns]

# %%
new=target.drop("thal",axis=1)
new
# Out:
#      thals
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 903      2
# 904      2
# 905      1
# 906      0
# 907      2
#
# [908 rows x 1 columns]

# %%
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
features=df.drop(["fbs","restecg","thalch","exang","oldpeak","slope","num","thal"],axis=1)
features
# Out:
#      age   sex               cp  trestbps  chol
# 0     63  Male   typical angina       145   233
# 1     41  Male  atypical angina       135   203
# 2     57  Male     asymptomatic       140   192
# 3     52  Male   typical angina       118   186
# 4     57  Male     asymptomatic       110   201
# ..   ...   ...              ...       ...   ...
# 903   53  Male     asymptomatic       125     0
# 904   62  Male     asymptomatic       166   170
# 905   56  Male      non-anginal       170     0
# 906   56  Male      non-anginal       144   208
# 907   57  Male     asymptomatic       142   277
#
# [908 rows x 5 columns]

# %%
le=LabelEncoder()
le_sex=LabelEncoder()
le_cp=LabelEncoder()

# %%
features["gender"]=le_sex.fit_transform(features["sex"])
features["cpp"]=le_cp.fit_transform(features["cp"])
features
# Out:
#      age   sex               cp  trestbps  chol  gender  cpp
# 0     63  Male   typical angina       145   233       1    3
# 1     41  Male  atypical angina       135   203       1    1
# 2     57  Male     asymptomatic       140   192       1    0
# 3     52  Male   typical angina       118   186       1    3
# 4     57  Male     asymptomatic       110   201       1    0
# ..   ...   ...              ...       ...   ...     ...  ...
# 903   53  Male     asymptomatic       125     0       1    0
# 904   62  Male     asymptomatic       166   170       1    0
# 905   56  Male      non-anginal       170     0       1    2
# 906   56  Male      non-anginal       144   208       1    2
# 907   57  Male     asymptomatic       142   277       1    0
#
# [908 rows x 7 columns]

# %%
featuress=features.drop(["sex","cp"],axis=1)
featuress.head()
# Out:
#    age  trestbps  chol  gender  cpp
# 0   63       145   233       1    3
# 1   41       135   203       1    1
# 2   57       140   192       1    0
# 3   52       118   186       1    3
# 4   57       110   201       1    0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(featuress,new,test_size=0.2)

# %%
x_train.head()
# Out:
#      age  trestbps  chol  gender  cpp
# 328   42       120   198       1    1
# 829   68       135     0       1    0
# 554   52       130   298       1    0
# 123   47       130   253       1    2
# 195   49       120   297       1    0

# %%
len(x_train)
# Out:
# 726

# %%
y_train.head()
# Out:
#      thals
# 328      0
# 829      2
# 554      1
# 123      1
# 195      1

# %%
len(y_train)
# Out:
# 726

# %%
x_test.head()
# Out:
#      age  trestbps  chol  gender  cpp
# 805   53       123   282       1    0
# 625   59       130   153       1    0
# 468   50       130   233       1    0
# 359   40       140   289       1    1
# 325   31       100   219       0    1

# %%
y_test.head()
# Out:
#      thals
# 805      2
# 625      1
# 468      2
# 359      1
# 325      1

# %%
from sklearn import tree

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
model=tree.DecisionTreeClassifier(max_depth=3)

# %%
model.fit(featuress,new)
plot_tree(model,fontsize=10)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 3
#       1 model.fit(featuress,new)
#       2 plot_tree(model,fontsize=10)
# ----> 3 plot.show()
#
# NameError: name 'plot' is not defined

# %%
model.predict([[53,123,282,1,0]])
# Out:
# C:\Users\mvish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([2])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import plot_tree
import numpy as np

# %%
# Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Train the model
model = LogisticRegression(max_iter=200)
model.fit(x_train, y_train)

# Predict on the testing set
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
accuracy
# Out:
# C:\Users\mvish\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5054945054945055

# %%
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# print(f'ROC AUC: {roc_auc:.4f}') # Uncomment if binary or multi-class binarized

# Additional evaluation metrics
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# Accuracy: 0.5055
# Precision: 0.4227
# Recall: 0.5055
# F1-score: 0.4589
# Confusion Matrix:
# [[ 0 13 17]
#  [ 0 49 24]
#  [ 0 36 43]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.50      0.67      0.57        73
#            2       0.51      0.54      0.53        79
#
#     accuracy                           0.51       182
#    macro avg       0.34      0.41      0.37       182
# weighted avg       0.42      0.51      0.46       182

# %%
param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

# %%
model=tree.DecisionTreeClassifier()

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10}
# Best Cross-Validation Score: 0.42423240434577236

# %%
best_model = grid_search.best_estimator_

# Predict on the testing set
y_pred = best_model.predict(x_test)

# %%
k
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 3
#       1 featurees=featuress.columns.tolist()
#       2 plt.figure(figsize=(12, 8))
# ----> 3 plot_tree(best_model, feature_names=featurees.columns, class_names=[str(i) for i in np.unique(new)], filled=True, rounded=True)
#       4 plt.show()
#       6 # Get feature importance
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
featurees=featuress.columns.tolist()
featurees
# Out:
# ['age', 'trestbps', 'chol', 'gender', 'cpp']

# %%
1. Common Hyperparameters of Decision Tree Models and Their Effects
Decision tree models have several hyperparameters that can significantly impact their performance. Here are some common ones:

max_depth: The maximum depth of the tree. This limits the number of splits in the tree.

min_samples_split: The minimum number of samples required to split an internal node.
max_features: The number of features to consider when looking for the best split.

 Difference Between Label Encoding and One-Hot Encoding
Label Encoding and One-Hot Encoding are two common methods for converting categorical data into numerical format, which is necessary for many machine learning algorithms.
